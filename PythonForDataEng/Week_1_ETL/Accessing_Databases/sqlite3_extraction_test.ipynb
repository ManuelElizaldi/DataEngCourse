# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('Practice_Movies copy.db')
cursor = conn.cursor

query = 'SELECT * FROM movie_data'

df = pd.read_sql(query, conn)

df
# Out:
#                                  Film  Year  RottenTomatoesRank
# 0               It Happened One Night  1934                   1
# 1                        Citizen Kane  1941                   2
# 2                    The Wizard of Oz  1939                   3
# 3                        Modern Times  1936                   4
# 4                       Black Panther  2018                   5
# 5                            Parasite  2019                   6
# 6                   Avengers: Endgame  2019                   7
# 7                          Casablanca  1942                   8
# 8                           Lady Bird  2017                  12
# 9                             Get Out  2017                  15
# 10                      The Godfather  1972                  17
# 11                 Mad Max: Fury Road  2015                  18
# 12  Spider-Man: Into the Spider-verse  2018                  19
# 13                          Moonlight  2016                  20
# ...
